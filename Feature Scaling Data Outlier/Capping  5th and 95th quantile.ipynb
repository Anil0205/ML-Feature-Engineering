# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_boston

# %%
data = load_boston()

# %%
dir(data)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target']

# %%
data.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
df = pd.DataFrame(data.data,columns = data.feature_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df['target'] = data.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df = df[['CRIM','RM','LSTAT']]

# %%
df.head()
# Out:
#       CRIM     RM  LSTAT
# 0  0.00632  6.575   4.98
# 1  0.02731  6.421   9.14
# 2  0.02729  7.185   4.03
# 3  0.03237  6.998   2.94
# 4  0.06905  7.147   5.33

# %%
df.isnull().sum()
# Out:
# CRIM     0
# RM       0
# LSTAT    0
# dtype: int64

# %%
import scipy.stats as stats

# %%
def fun(df,var):
    plt.figure(figsize = (15,5))
    plt.subplot(1,3,1)
    df[var].hist(bins = 30)
    plt.subplot(1,3,2)
    stats.probplot(df[var],dist='norm',plot = plt)
    plt.subplot(1,3,3)
    sns.boxplot(y = df[var])
    plt.ylabel("values")
    plt.show()

# %%
fun(df,'CRIM')

# %%
fun(df,'RM')

# %%
fun(df,'LSTAT')

# %% [markdown]
# ### capping with mean

# %%
def iqr(df,var,value):
    upper = df[var].quantile(0.95)
    
    
    lower = df[var].quantile(0.05)
    
    return upper , lower

# %%
upper_limit_lstat , lower_limit_lstat = iqr(df,'LSTAT',3)
upper_limit_lstat,lower_limit_lstat
# Out:
# (26.8075, 3.7075)

# %%
upper_limit_rm , lower_limit_rm = iqr(df,'RM',3)
upper_limit_rm,lower_limit_rm
# Out:
# (7.5875, 5.314)

# %%
upper_limit_crim , lower_limit_crim = iqr(df,'CRIM',3)
upper_limit_crim,lower_limit_crim
# Out:
# (15.78915, 0.027909999999999997)

# %%
df['LSTAT'] = np.where(df['LSTAT'] > upper_limit_lstat , upper_limit_lstat , 
                         np.where(df['LSTAT'] < lower_limit_lstat , lower_limit_lstat , df['LSTAT']))

# %%
df['RM'] = np.where(df['RM'] > upper_limit_rm , upper_limit_rm , 
                         np.where(df['RM'] < lower_limit_rm , lower_limit_rm , df['RM']))

# %%
df['CRIM'] = np.where(df['CRIM'] > upper_limit_crim , upper_limit_crim , 
                         np.where(df['CRIM'] < lower_limit_crim , lower_limit_crim , df['CRIM']))

# %%
def fun(data,var):
    plt.figure(figsize = (15,5))
    plt.subplot(1,3,1)
    data[var].hist(bins = 30)
    plt.subplot(1,3,2)
    stats.probplot(data[var],dist='norm',plot = plt)
    plt.subplot(1,3,3)
    sns.boxplot(y = data[var])
    plt.ylabel("values")
    plt.show()

# %%
fun(df,'LSTAT')

# %%
fun(df,'RM')

# %%
fun(df,'CRIM')

# %% [markdown]
# ### Using Feature engine

# %%
from feature_engine.outliers import Winsorizer

# %%
reg = Winsorizer(capping_method='quantiles',tail='both',fold = 0.05 , variables=['RM'])

# %%
reg.fit(df)
# Out:
# Winsorizer(capping_method='quantiles', fold=0.05, tail='both', variables=['RM'])

# %%
reg.left_tail_caps_
# Out:
# {'RM': 5.3215}

# %%
reg.right_tail_caps_
# Out:
# {'RM': 7.570625}

# %%
data = reg.transform(df)

# %%
fun(df,'RM')

# %%
fun(data,'RM')
